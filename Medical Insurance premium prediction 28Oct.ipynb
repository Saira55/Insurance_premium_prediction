# %%
# !pip install jupyterthemes

from jupyterthemes import jtplot
jtplot.style(theme= "gruvboxl", context='notebook', ticks=True, grid=False)
# Out:
# Requirement already satisfied: jupyterthemes in d:\anaconda\k\lib\site-packages (0.20.0)
# Requirement already satisfied: jupyter-core in d:\anaconda\k\lib\site-packages (from jupyterthemes) (5.3.0)
# Requirement already satisfied: notebook>=5.6.0 in d:\anaconda\k\lib\site-packages (from jupyterthemes) (6.5.4)
# Requirement already satisfied: ipython>=5.4.1 in d:\anaconda\k\lib\site-packages (from jupyterthemes) (8.12.0)
# Requirement already satisfied: matplotlib>=1.4.3 in d:\anaconda\k\lib\site-packages (from jupyterthemes) (3.7.1)
# Requirement already satisfied: lesscpy>=0.11.2 in d:\anaconda\k\lib\site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: backcall in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: pickleshare in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.15.1)
# Requirement already satisfied: stack-data in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: traitlets>=5 in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: colorama in d:\anaconda\k\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.6)
# Requirement already satisfied: ply in d:\anaconda\k\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\k\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: jinja2 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: argon2-cffi in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (7.4.9)
# Requirement already satisfied: ipython-genutils in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.6)
# Requirement already satisfied: ipykernel in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: prometheus-client in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in d:\anaconda\k\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.5.5)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\k\lib\site-packages (from jupyter-core->jupyterthemes) (2.5.2)
# Requirement already satisfied: pywin32>=300 in d:\anaconda\k\lib\site-packages (from jupyter-core->jupyterthemes) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\k\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: entrypoints in d:\anaconda\k\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in d:\anaconda\k\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in d:\anaconda\k\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: lxml in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.12.2)
# Requirement already satisfied: bleach in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: tinycss2 in d:\anaconda\k\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: fastjsonschema in d:\anaconda\k\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\k\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: wcwidth in d:\anaconda\k\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\k\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\anaconda\k\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\k\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\k\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\k\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.6.7)
# Requirement already satisfied: psutil in d:\anaconda\k\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: executing in d:\anaconda\k\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\k\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\k\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\k\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\k\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\k\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.5.0)
# Requirement already satisfied: websocket-client in d:\anaconda\k\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\k\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\k\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.4)
# Requirement already satisfied: webencodings in d:\anaconda\k\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\k\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\k\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.2.0)
# Requirement already satisfied: pycparser in d:\anaconda\k\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)

# %% [markdown]
# ### 2. Import Libraries and data set

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
insurance_df=pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### 3. Exploratory Data Analysis

# %%
insurance_df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.heatmap(insurance_df.isnull(), yticklabels= False, cbar=False, cmap="Blues")
# Out:
# <Axes: >

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# group by region

df_region=insurance_df.groupby(by='region').mean()
df_region
# Out:
# C:\Users\Uzma\AppData\Local\Temp\ipykernel_6992\3493499268.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_region=insurance_df.groupby(by='region').mean()
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# Practice 1

# %%
df_age=insurance_df.groupby(by='age').mean()
df_age
# Out:
# C:\Users\Uzma\AppData\Local\Temp\ipykernel_6992\2840194224.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_age=insurance_df.groupby(by='age').mean()
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# 41   31.506852  1.407407   9653.745650
# 42   30.328148  1.000000  13061.038669
# 43   30.204444  1.629630  19267.278653
# 44   30.844259  1.222222  15859.396587
# 45   29.778966  1.482759  14830.199856
# 46   31.340862  1.620690  14342.590639
# 47   30.664310  1.379310  17653.999593
# 48   31.925690  1.310345  14632.500445
# 49   30.313929  1.500000  12696.006264
# 50   31.132241  1.310345  15663.003301
# 51   31.727069  1.103448  15682.255867
# 52   32.936034  1.482759  18256.269719
# 53   30.360893  1.250000  16020.930755
# 54   31.234286  1.428571  18758.546475
# 55   31.950000  0.961538  16164.545488
# 56   31.600962  0.769231  15025.515837
# 57   30.844423  0.615385  16447.185250
# 58   32.718200  0.240000  13878.928112
# 59   30.572000  1.200000  18895.869532
# 60   30.332826  0.347826  21979.418507
# 61   32.548261  0.739130  22024.457609
# 62   32.342609  0.565217  19163.856573
# 63   31.923478  0.565217  19884.998461
# 64   32.976136  0.772727  23275.530837

# %%
plt.figure(figsize = (15, 6))
sns.scatterplot(data=insurance_df, x='age', y='charges')
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap

ylorrd_cmap = sns.color_palette("YlOrRd", as_cmap=True)
custom_cmap = LinearSegmentedColormap.from_list("custom_ylorrd", ylorrd_cmap(np.linspace(0.9, 1)))


# Generate your correlation matrix
correlation_matrix = insurance_df[['age', 'charges']].corr()
plt.figure(figsize = (4, 4))
# Create the heatmap with the custom colormap
sns.heatmap(correlation_matrix, annot=True, cmap=custom_cmap)
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap

ylorrd_cmap = sns.color_palette("PuBuGn", as_cmap=True)
custom_cmap = LinearSegmentedColormap.from_list("custom_ylorrd", ylorrd_cmap(np.linspace(0.9, 1)))


# Generate your correlation matrix
correlation_matrix = insurance_df[['age', 'charges']].corr()
plt.figure(figsize = (6, 6))
# Create the heatmap with the custom colormap
sns.heatmap(correlation_matrix, annot=True, cmap=custom_cmap)
plt.show()

# %% [markdown]
# ### 4. Perform Feature Engineering

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=insurance_df, x='smoker')
plt.show()

# %%
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=insurance_df, x='region')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=insurance_df, x='sex')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=insurance_df, x='smoker', hue='sex')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(insurance_df, x='smoker', hue='region')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=insurance_df, hue='children', x='region')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=insurance_df, x='charges', y='smoker')
plt.show()

# %%
plt.figure(figsize=(6,2))

# Define custom properties
boxprops = {'edgecolor': 'none', 'linewidth': 0.5}
whiskerprops = {'color': 'green', 'linewidth': 0.5}
capprops = {'color': 'green', 'linewidth': 0.5}
flierprops = {'markeredgecolor': 'green', 'markerfacecolor': 'green'}
medianprops = {'color': 'green', 'linewidth': 0.5}

sns.boxplot(data=insurance_df, x='charges', y='smoker', palette={"yes": "green", "no": "orange"},
            boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops, flierprops=flierprops, notch=True,
            medianprops=medianprops, width=0.2)

plt.show()

# %%
plt.figure(figsize=(6,4))

# Define custom properties
boxprops = {'edgecolor': 'none'}
whiskerprops = {'color': 'green'}
capprops = {'color': 'green'}
flierprops = {'markeredgecolor': 'green', 'markerfacecolor': 'green'}

sns.boxplot(data=insurance_df, x='charges', y='smoker', palette={"yes": "green", "no": "orange"},
            boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops, flierprops=flierprops, notch=True)

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=insurance_df, x='charges', y='smoker', hue='region')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=insurance_df, x='charges', y='sex', hue='smoker')
plt.show()

# %%
plt.figure(figsize=(10, 8))

# Top plot: Box plot
plt.subplot(2, 1, 1)
sns.boxplot(x='charges', y='smoker', data=insurance_df, palette={"yes": "green", "no": "orange"}, orient='h')
plt.title('Annual Medical Charges')# Bottom plot: Stacked histogram
plt.subplot(2, 1, 2)

bins = np.linspace(insurance_df.charges.min(), insurance_df.charges.max(), 30)
smokers = insurance_df[insurance_df.smoker == 'yes']
non_smokers = insurance_df[insurance_df.smoker == 'no']

plt.hist([smokers['charges'], non_smokers['charges']], bins=bins, stacked=True, color=['green', 'orange'], label=['yes', 'no'], rwidth=0.9)

plt.xlabel('charges')
plt.ylabel('count')
plt.legend(title='smoker')

# %%
plt.subplot(2, 1, 1)
sns.boxplot(x='charges', y='smoker', data=insurance_df, palette={"yes": "green", "no": "orange"}, orient='h', notch=True)
plt.title('Annual Medical Charges')

# Remove x-axis label for the box plot
plt.xlabel('')
plt.setp(plt.gca().get_xticklabels(), visible=False)

# Bottom plot: Stacked histogram
plt.subplot(2, 1, 2)

bins = np.linspace(insurance_df.charges.min(), insurance_df.charges.max(), 30)
smokers = insurance_df[insurance_df.smoker == 'yes']
non_smokers = insurance_df[insurance_df.smoker == 'no']

plt.hist([smokers['charges'], non_smokers['charges']], bins=bins, stacked=True, color=['green', 'orange'], label=['yes', 'no'], rwidth=0.9)

plt.xlabel('charges')
plt.ylabel('count')
plt.legend(title='smoker')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create a grid specification with 3 rows; the boxplot will take 1 row and the histogram will take 2 rows
gs = gridspec.GridSpec(3, 1)

plt.figure(figsize=(6, 4))

# Top plot: Notched Boxplot using the first row of the grid spec
ax1 = plt.subplot(gs[0])
sns.boxplot(x='charges', y='smoker', data=insurance_df, palette={"yes": "green", "no": "orange"}, orient='h', notch=True, ax=ax1)
plt.title('Annual Medical Charges')

# Remove x-axis label for the box plot
plt.xlabel('')
plt.setp(plt.gca().get_xticklabels(), visible=False)

# Bottom plot: Stacked histogram using the second and third rows of the grid spec
ax2 = plt.subplot(gs[1:])
bins = np.linspace(insurance_df.charges.min(), insurance_df.charges.max(), 30)
smokers = insurance_df[insurance_df.smoker == 'yes']
non_smokers = insurance_df[insurance_df.smoker == 'no']

plt.hist([smokers['charges'], non_smokers['charges']], bins=bins, stacked=True, color=['green', 'orange'], label=['yes', 'no'], rwidth=0.9)

plt.xlabel('charges')
plt.ylabel('count')
plt.legend(title='smoker')

plt.tight_layout()
plt.show()

# %%
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['sex']=insurance_df['sex'].apply(lambda x:0  if x=='female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
insurance_df['smoker']=insurance_df['smoker'].apply(lambda x:0 if x=='no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies=pd.get_dummies(insurance_df['region'], drop_first=True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df=pd.concat([insurance_df, region_dummies], axis=1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          1
# 4   32    1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
# drop original region colum
insurance_df.drop(['region'], axis=1, inplace=True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# ### Perform data Visualization

# %%
insurance_df[['age', 'sex', 'bmi','children','smoker','charges']].hist(bins=30, figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>],
#        [<Axes: title={'center': 'bmi'}>,
#         <Axes: title={'center': 'children'}>],
#        [<Axes: title={'center': 'smoker'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
sns.pairplot(insurance_df, hue='sex',markers=["o", "s"], palette="Set2");

# %%
sns.pairplot(insurance_df,kind="scatter", diag_kind="hist", markers=["o", "s", "D"])

# %%
plt.figure(figsize = (15, 6))
sns.regplot(data=insurance_df, x='age', y='charges')
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(data=insurance_df, x='bmi', y='charges')
plt.show()

# %%
insurance_df.corr()

# %%
from matplotlib.colors import LinearSegmentedColormap

ylorrd_cmap = sns.color_palette("YlOrRd", as_cmap=True)
custom_cmap = LinearSegmentedColormap.from_list("custom_ylorrd", ylorrd_cmap(np.linspace(0.9, 1)))


# Generate your correlation matrix
correlation_matrix = insurance_df[['age', 'charges']].corr()
plt.figure(figsize = (4, 4))
# Create the heatmap with the custom colormap
sns.heatmap(correlation_matrix, annot=True, cmap=custom_cmap)
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap

ylorrd_cmap = sns.color_palette("twilight_shifted", as_cmap=True)
custom_cmap = LinearSegmentedColormap.from_list("custom_ylorrd", ylorrd_cmap(np.linspace(0.7, 1)))


correlation_matrix = insurance_df.corr()

# Create the heatmap
plt.figure(figsize=(8,8))
sns.heatmap(data=correlation_matrix, annot=True, cmap=custom_cmap)
plt.show()

# %% [markdown]
# ### 6. Create training and testing dataset

# %%
insurance_df.columns

# %%
X=insurance_df.drop(columns=['charges'])

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y=insurance_df['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X=np.array(X).astype('float32')
y=np.array(y).astype('float32')

# %%
y=y.reshape(-1,1)

# %%
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
y.shape   #converted to matrix
# Out:
# (1338, 1)

# %%
y
# Out:
# array([[16884.924 ],
#        [ 1725.5522],
#        [ 4449.462 ],
#        ...,
#        [ 1629.8335],
#        [ 2007.945 ],
#        [29141.36  ]], dtype=float32)

# %%
# scaling the data
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x=StandardScaler()
X=scaler_x.fit_transform(X)

scaler_y=StandardScaler()
y=scaler_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=10)

# %%
X_train.shape
# Out:
# (1070, 8)

# %%
X_test.shape
# Out:
# (268, 8)

# %% [markdown]
# ###  7. Train and Evaluate a Linear Regression Model in Sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regression_model_sklearn=LinearRegression()
regression_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model_sklearn_accuracy=regression_model_sklearn.score(X_test, y_test)
regression_model_sklearn_accuracy
# Out:
# 0.6953286434739431

# %%
y_predict=regression_model_sklearn.predict(X_test)

# %%
y_predict_orig=scaler_y.inverse_transform(y_predict)
y_test_orig=scaler_y.inverse_transform(y_test)

# %%
k=X_test.shape[1]
n=len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

# %%
RMSE=float(format(np.sqrt(mean_squared_error(y_test_orig,y_predict_orig)), '.3f'))
MSE=mean_squared_error(y_test_orig,y_predict_orig)
MAE=mean_absolute_error(y_test_orig,y_predict_orig)
r2=r2_score(y_test_orig,y_predict_orig)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)

print('RMSE=', RMSE, '\nMSE=', MSE, '\nMAE=', MAE, '\nR2=',r2, '\nAdjusted R2=', adj_r2)
# Out:
# RMSE= 6536.847
# MSE= 42730370.0
# MAE= 4555.0996
# R2= 0.6953286644091601
# Adjusted R2= 0.6859179667847326

# %% [markdown]
# ### 8 Train and evaluate an Artificial Neural Network-based regression Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
ANN_model=keras.Sequential()
ANN_model.add(Dense(50,input_dim=8)) # match with imputs
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss='mse', optimizer='adam')
ANN_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 50)                450
#
#  activation_5 (Activation)   (None, 50)                0
#
#  dense_7 (Dense)             (None, 150)               7650
#
#  activation_6 (Activation)   (None, 150)               0
#
#  dense_8 (Dense)             (None, 150)               22650
#
#  activation_7 (Activation)   (None, 150)               0
#
#  dense_9 (Dense)             (None, 50)                7550
#
#  activation_8 (Activation)   (None, 50)                0
#
#  dense_10 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 38351 (149.81 KB)
# Trainable params: 38351 (149.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')
epochs_hist=ANN_model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 8ms/step - loss: 0.3043 - val_loss: 0.1925
# Epoch 2/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1654 - val_loss: 0.1746
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1466 - val_loss: 0.1653
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1457 - val_loss: 0.1856
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1337 - val_loss: 0.1647
# Epoch 6/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1301 - val_loss: 0.1700
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1248 - val_loss: 0.1875
# Epoch 8/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1197 - val_loss: 0.1764
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1245 - val_loss: 0.1711
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1116 - val_loss: 0.1893
# Epoch 11/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1171 - val_loss: 0.1875
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1117 - val_loss: 0.1819
# Epoch 13/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1104 - val_loss: 0.1992
# Epoch 14/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1123 - val_loss: 0.1918
# Epoch 15/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1049 - val_loss: 0.1877
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1000 - val_loss: 0.1842
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0997 - val_loss: 0.1956
# Epoch 18/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0987 - val_loss: 0.2068
# Epoch 19/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1031 - val_loss: 0.1918
# Epoch 20/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0946 - val_loss: 0.1969
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0935 - val_loss: 0.1971
# Epoch 22/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0908 - val_loss: 0.1954
# Epoch 23/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0915 - val_loss: 0.2092
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0929 - val_loss: 0.1933
# Epoch 25/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0859 - val_loss: 0.2041
# Epoch 26/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0828 - val_loss: 0.2138
# Epoch 27/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0855 - val_loss: 0.2087
# Epoch 28/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0776 - val_loss: 0.2105
# Epoch 29/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0796 - val_loss: 0.2231
# Epoch 30/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0816 - val_loss: 0.1974
# Epoch 31/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0794 - val_loss: 0.2234
# Epoch 32/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0739 - val_loss: 0.2099
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0774 - val_loss: 0.2104
# Epoch 34/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0765 - val_loss: 0.2126
# Epoch 35/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0744 - val_loss: 0.2288
# Epoch 36/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0708 - val_loss: 0.2294
# Epoch 37/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0701 - val_loss: 0.2195
# Epoch 38/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0685 - val_loss: 0.2337
# Epoch 39/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0685 - val_loss: 0.2311
# Epoch 40/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0668 - val_loss: 0.2258
# Epoch 41/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0648 - val_loss: 0.2327
# Epoch 42/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0624 - val_loss: 0.2172
# Epoch 43/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0667 - val_loss: 0.2415
# Epoch 44/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0625 - val_loss: 0.2464
# Epoch 45/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0587 - val_loss: 0.2393
# Epoch 46/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0616 - val_loss: 0.2396
# Epoch 47/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0597 - val_loss: 0.2275
# Epoch 48/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0553 - val_loss: 0.2466
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0553 - val_loss: 0.2327
# Epoch 50/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0578 - val_loss: 0.2227
# Epoch 51/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0584 - val_loss: 0.2549
# Epoch 52/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0502 - val_loss: 0.2450
# Epoch 53/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0539 - val_loss: 0.2383
# Epoch 54/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0520 - val_loss: 0.2294
# Epoch 55/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0550 - val_loss: 0.2451
# Epoch 56/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0512 - val_loss: 0.2378
# Epoch 57/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0476 - val_loss: 0.2431
# Epoch 58/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0504 - val_loss: 0.2682
# Epoch 59/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0495 - val_loss: 0.2595
# Epoch 60/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0524 - val_loss: 0.2496
# Epoch 61/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0484 - val_loss: 0.2640
# Epoch 62/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0472 - val_loss: 0.2512
# Epoch 63/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0429 - val_loss: 0.2535
# Epoch 64/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.2869
# Epoch 65/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0499 - val_loss: 0.2511
# Epoch 66/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0431 - val_loss: 0.2690
# Epoch 67/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0431 - val_loss: 0.2455
# Epoch 68/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0465 - val_loss: 0.2464
# Epoch 69/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.2793
# Epoch 70/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0431 - val_loss: 0.2701
# Epoch 71/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.2695
# Epoch 72/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0453 - val_loss: 0.2755
# Epoch 73/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0423 - val_loss: 0.2696
# Epoch 74/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.2594
# Epoch 75/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0384 - val_loss: 0.2663
# Epoch 76/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0398 - val_loss: 0.2480
# Epoch 77/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0435 - val_loss: 0.2645
# Epoch 78/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0403 - val_loss: 0.2603
# Epoch 79/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0344 - val_loss: 0.2631
# Epoch 80/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0311 - val_loss: 0.2690
# Epoch 81/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0350 - val_loss: 0.2604
# Epoch 82/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0344 - val_loss: 0.2726
# Epoch 83/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0334 - val_loss: 0.2483
# Epoch 84/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0361 - val_loss: 0.2445
# Epoch 85/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0363 - val_loss: 0.2728
# Epoch 86/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.2703
# Epoch 87/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.2373
# Epoch 88/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.2525
# Epoch 89/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0321 - val_loss: 0.2635
# Epoch 90/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0316 - val_loss: 0.2770
# Epoch 91/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0394 - val_loss: 0.2591
# Epoch 92/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0365 - val_loss: 0.2892
# Epoch 93/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0339 - val_loss: 0.2693
# Epoch 94/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.2540
# Epoch 95/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.2790
# Epoch 96/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.2662
# Epoch 97/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.2566
# Epoch 98/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0321 - val_loss: 0.2823
# Epoch 99/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.2546
# Epoch 100/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.2602

# %%
result=ANN_model.evaluate(X_test, y_test)
accuracy_ANN=1-result
print("Accuracy :{}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2896
# Accuracy :0.7103507220745087

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation loss')
plt.legend(['Training loss', 'Validation loss'])

# %% [markdown]
# As validation is going high, model is overfitting the data

# %%
y_predict=ANN_model.predict(X_test)
plt.plot(y_test, y_predict, '^', color='r')
plt.xlabel('Model Prediction')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig=scaler_y.inverse_transform(y_predict)
y_test_orig=scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color='r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k=X_test.shape[1]
n=len(X_test)
n
# Out:
# 268

# %%
RMSE=float(format(np.sqrt(mean_squared_error(y_test_orig,y_predict_orig)), '.3f'))
MSE=mean_squared_error(y_test_orig,y_predict_orig)
MAE=mean_absolute_error(y_test_orig,y_predict_orig)
r2=r2_score(y_test_orig,y_predict_orig)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)

print('RMSE=', RMSE, '\nMSE=', MSE, '\nMAE=', MAE, '\nR2=',r2, '\nAdjusted R2=', adj_r2)
# Out:
# RMSE= 6515.061
# MSE= 42446016.0
# MAE= 3842.0508
# R2= 0.6973561524521594
# Adjusted R2= 0.6880080799410293

# %%
ANN_model=keras.Sequential()
ANN_model.add(Dense(50,input_dim=8)) # match with imputs
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss='mse', optimizer='adam')
ANN_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 50)                450
#
#  activation_10 (Activation)  (None, 50)                0
#
#  dense_13 (Dense)            (None, 150)               7650
#
#  activation_11 (Activation)  (None, 150)               0
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_14 (Dense)            (None, 150)               22650
#
#  activation_12 (Activation)  (None, 150)               0
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_15 (Dense)            (None, 50)                7550
#
#  activation_13 (Activation)  (None, 50)                0
#
#  dense_16 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 38351 (149.81 KB)
# Trainable params: 38351 (149.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')
epochs_hist=ANN_model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 5ms/step - loss: 0.7278 - val_loss: 0.3800
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4122 - val_loss: 0.2207
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3076 - val_loss: 0.2151
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2773 - val_loss: 0.2182
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2655 - val_loss: 0.2357
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2285 - val_loss: 0.1815
# Epoch 7/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2297 - val_loss: 0.1880
# Epoch 8/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2204 - val_loss: 0.1846
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2153 - val_loss: 0.1855
# Epoch 10/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1948 - val_loss: 0.1737
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2096 - val_loss: 0.1672
# Epoch 12/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2190 - val_loss: 0.1939
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1989 - val_loss: 0.1710
# Epoch 14/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2052 - val_loss: 0.1804
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1961 - val_loss: 0.1855
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2147 - val_loss: 0.2138
# Epoch 17/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2036 - val_loss: 0.1931
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1802 - val_loss: 0.1922
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2002 - val_loss: 0.2161
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1909 - val_loss: 0.1887
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1807 - val_loss: 0.1900
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1743 - val_loss: 0.1905
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1884 - val_loss: 0.1960
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1830 - val_loss: 0.1975
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1828 - val_loss: 0.1874
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1740 - val_loss: 0.1861
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1730 - val_loss: 0.2030
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1780 - val_loss: 0.1844
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1696 - val_loss: 0.1691
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1675 - val_loss: 0.1716
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1763 - val_loss: 0.1825
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1658 - val_loss: 0.1735
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1651 - val_loss: 0.1932
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1672 - val_loss: 0.1764
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1731 - val_loss: 0.1879
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1704 - val_loss: 0.1777
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1591 - val_loss: 0.1772
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1643 - val_loss: 0.1918
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1684 - val_loss: 0.1788
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1668 - val_loss: 0.1887
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1507 - val_loss: 0.1928
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1564 - val_loss: 0.1665
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1624 - val_loss: 0.1736
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1512 - val_loss: 0.1766
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1586 - val_loss: 0.1872
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1623 - val_loss: 0.1753
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1602 - val_loss: 0.1805
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1656 - val_loss: 0.1645
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1478 - val_loss: 0.1746
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1531 - val_loss: 0.1791
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1617 - val_loss: 0.1933
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1547 - val_loss: 0.1673
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1448 - val_loss: 0.1716
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1622 - val_loss: 0.1832
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1485 - val_loss: 0.1761
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1477 - val_loss: 0.1764
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1439 - val_loss: 0.1749
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1646 - val_loss: 0.1850
# Epoch 59/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1397 - val_loss: 0.1752
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1580 - val_loss: 0.2043
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1404 - val_loss: 0.1720
# Epoch 62/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1569 - val_loss: 0.1970
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1498 - val_loss: 0.2094
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1496 - val_loss: 0.1784
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1631 - val_loss: 0.2145
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1362 - val_loss: 0.1804
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1427 - val_loss: 0.2051
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1375 - val_loss: 0.1865
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1377 - val_loss: 0.2007
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1387 - val_loss: 0.1857
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1375 - val_loss: 0.1785
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1360 - val_loss: 0.1944
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1311 - val_loss: 0.1825
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1352 - val_loss: 0.1778
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1297 - val_loss: 0.1935
# Epoch 76/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1397 - val_loss: 0.1825
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1284 - val_loss: 0.1920
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1360 - val_loss: 0.1840
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1261 - val_loss: 0.1875
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1331 - val_loss: 0.1844
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1267 - val_loss: 0.1826
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1313 - val_loss: 0.1755
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1323 - val_loss: 0.1901
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1249 - val_loss: 0.1920
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1325 - val_loss: 0.1752
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1342 - val_loss: 0.1978
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1251 - val_loss: 0.1862
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1262 - val_loss: 0.1778
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1323 - val_loss: 0.1944
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1236 - val_loss: 0.2061
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1230 - val_loss: 0.1980
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1334 - val_loss: 0.2019
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1239 - val_loss: 0.1892
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1250 - val_loss: 0.2009
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1166 - val_loss: 0.1884
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1160 - val_loss: 0.1990
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1203 - val_loss: 0.2131
# Epoch 98/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1234 - val_loss: 0.2061
# Epoch 99/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1235 - val_loss: 0.2074
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1286 - val_loss: 0.2032

# %%
result=ANN_model.evaluate(X_test, y_test)
accuracy_ANN=1-result
print("Accuracy :{}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2169
# Accuracy :0.7831336706876755

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation loss')
plt.legend(['Training loss', 'Validation loss'])

# %%
y_predict=ANN_model.predict(X_test)
plt.plot(y_test, y_predict, '^', color='r')
plt.xlabel('Model Prediction')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig=scaler_y.inverse_transform(y_predict)
y_test_orig=scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color='r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k=X_test.shape[1]
n=len(X_test)
n
# Out:
# 268

# %%
RMSE=float(format(np.sqrt(mean_squared_error(y_test_orig,y_predict_orig)), '.3f'))
MSE=mean_squared_error(y_test_orig,y_predict_orig)
MAE=mean_absolute_error(y_test_orig,y_predict_orig)
r2=r2_score(y_test_orig,y_predict_orig)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)

print('RMSE=', RMSE, '\nMSE=', MSE, '\nMAE=', MAE, '\nR2=',r2, '\nAdjusted R2=', adj_r2)
# Out:
# RMSE= 5637.392
# MSE= 31780190.0
# MAE= 3602.0015
# R2= 0.7734044110318805
# Adjusted R2= 0.7664053194807416

# %%
from keras.regularizers import l1_l2

# %%
ANN_model=keras.Sequential()
ANN_model.add(Dense(50,input_dim=8)) # match with imputs
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150, kernel_regularizer=l1_l2(l1=0.01, l2=0.01), kernel_initializer='he_normal'))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150, kernel_regularizer=l1_l2(l1=0.01, l2=0.01), kernel_initializer='he_normal'))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
optimizer = keras.optimizers.SGD(learning_rate=0.001)
ANN_model.compile(loss='mse', optimizer=optimizer)
ANN_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 50)                450
#
#  activation_14 (Activation)  (None, 50)                0
#
#  dense_18 (Dense)            (None, 150)               7650
#
#  activation_15 (Activation)  (None, 150)               0
#
#  dropout_2 (Dropout)         (None, 150)               0
#
#  dense_19 (Dense)            (None, 150)               22650
#
#  activation_16 (Activation)  (None, 150)               0
#
#  dropout_3 (Dropout)         (None, 150)               0
#
#  dense_20 (Dense)            (None, 50)                7550
#
#  activation_17 (Activation)  (None, 50)                0
#
#  dense_21 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 38351 (149.81 KB)
# Trainable params: 38351 (149.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer = keras.optimizers.SGD(learning_rate=0.001)
ANN_model.compile(optimizer=optimizer, loss='mean_squared_error')
epochs_hist=ANN_model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 6ms/step - loss: 41.1251 - val_loss: 39.8948
# Epoch 2/100
# 43/43 [==============================] - 0s 3ms/step - loss: 40.4792 - val_loss: 39.5583
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 39.8696 - val_loss: 39.2981
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/step - loss: 39.5494 - val_loss: 39.0432
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/step - loss: 39.3164 - val_loss: 38.8256
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 39.1155 - val_loss: 38.6187
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 38.8242 - val_loss: 38.4038
# Epoch 8/100
# 43/43 [==============================] - 0s 2ms/step - loss: 38.5572 - val_loss: 38.1918
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 38.3647 - val_loss: 37.9851
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 38.1470 - val_loss: 37.7772
# Epoch 11/100
# 43/43 [==============================] - 0s 3ms/step - loss: 37.9252 - val_loss: 37.5725
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 37.7221 - val_loss: 37.3759
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/step - loss: 37.4631 - val_loss: 37.1702
# Epoch 14/100
# 43/43 [==============================] - 0s 2ms/step - loss: 37.2804 - val_loss: 36.9686
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/step - loss: 37.0378 - val_loss: 36.7741
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/step - loss: 36.8928 - val_loss: 36.5879
# Epoch 17/100
# 43/43 [==============================] - 0s 2ms/step - loss: 36.6827 - val_loss: 36.3926
# Epoch 18/100
# 43/43 [==============================] - 0s 3ms/step - loss: 36.4728 - val_loss: 36.2042
# Epoch 19/100
# 43/43 [==============================] - 0s 3ms/step - loss: 36.2452 - val_loss: 36.0080
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/step - loss: 36.1022 - val_loss: 35.8181
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/step - loss: 35.9172 - val_loss: 35.6358
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/step - loss: 35.6996 - val_loss: 35.4456
# Epoch 23/100
# 43/43 [==============================] - 0s 3ms/step - loss: 35.5073 - val_loss: 35.2658
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 35.3239 - val_loss: 35.0822
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 35.1537 - val_loss: 34.8930
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 34.9748 - val_loss: 34.7082
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 34.7716 - val_loss: 34.5253
# Epoch 28/100
# 43/43 [==============================] - 0s 3ms/step - loss: 34.5817 - val_loss: 34.3457
# Epoch 29/100
# 43/43 [==============================] - 0s 3ms/step - loss: 34.4144 - val_loss: 34.1573
# Epoch 30/100
# 43/43 [==============================] - 0s 3ms/step - loss: 34.2040 - val_loss: 33.9780
# Epoch 31/100
#  1/43 [..............................] - ETA: 0s - loss: 33.8799

# %%
result=ANN_model.evaluate(X_test, y_test)
accuracy_ANN=1-result
print("Accuracy :{}".format(accuracy_ANN))

# %%
RMSE=float(format(np.sqrt(mean_squared_error(y_test_orig,y_predict_orig)), '.3f'))
MSE=mean_squared_error(y_test_orig,y_predict_orig)
MAE=mean_absolute_error(y_test_orig,y_predict_orig)
r2=r2_score(y_test_orig,y_predict_orig)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)

print('RMSE=', RMSE, '\nMSE=', MSE, '\nMAE=', MAE, '\nR2=',r2, '\nAdjusted R2=', adj_r2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
data = np.linspace(0, 1, 256).reshape(1, -1)
data = np.vstack([data, data])

# Display each colormap
names = ["Blues", "BrBG", "coolwarm", "Pastel1", 'Pastel2', 'Paired', 'Accent', 'Dark2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20','hsv', 'twilight', 'twilight_shifted', 'phase','BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr', 'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral','seismic','Blues', 'BuGn', 'BuPu', 'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd', 'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu', 'Reds', 'YlGn', 'YlGnBu', 'YlOrBr','YlOrRd']  # add more colormaps to the list
for name in names:
    fig, ax = plt.subplots(figsize=(2, 10))
    ax.set_title(name)
    ax.imshow(data, aspect='auto', cmap=plt.get_cmap(name))
    plt.axis('off')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
data = np.linspace(0, 1, 256).reshape(1, -1)
data = np.vstack([data, data])

# Display each colormap
names = ['coolwarm', 'PiYG', 'PRGn', 'PuOr', 'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral','seismic','Blues', 'BuGn', 'BuPu', 'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd', 'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu', 'Reds', 'YlGn', 'YlGnBu', 'YlOrBr','YlOrRd']  # add more colormaps to the list
for name in names:
    fig, ax = plt.subplots(figsize=(2, 10))
    ax.set_title(name)
    ax.imshow(data, aspect='auto', cmap=plt.get_cmap(name))
    plt.axis('off')
    plt.show()
